# %%
import os
import pandas as pd

# %%
def check_and_clean_csv(file_path, expected_interval='15min'):
    print(f"\nChecking {file_path}")
    try:
        df = pd.read_csv(file_path, parse_dates=['timestamp'])
    except Exception as e:
        print(f"Failed to load the file: {e}")
        return

    required_columns = {"timestamp", "open", "high", "low", "close", "volume", "turnover"}
    missing_columns = required_columns - set(df.columns)
    if missing_columns:
        print(f"Missing required columns: {missing_columns}")
        return

    if df.empty:
        print("The file is empty.")
        return

    # הסרת כפילויות לפי timestamp
    dup_ts = df["timestamp"].duplicated()
    if dup_ts.any():
        print(f"Removed {dup_ts.sum()} duplicate timestamps.")
        df = df[~dup_ts]

    # הסרת שורות עם ערכים חסרים
    null_rows = df[df.isnull().any(axis=1)]
    if not null_rows.empty:
        print(f"Removed {len(null_rows)} rows with missing values.")
        df = df.dropna()

    # מיון לפי timestamp אם לא ממויין
    if not df["timestamp"].is_monotonic_increasing:
        print("Timestamps were not sorted. Sorted them.")
        df = df.sort_values(by="timestamp")

    # הסרת כפילויות לפי symbol + timestamp
    if "symbol" in df.columns:
        dup_pairs = df.duplicated(subset=["symbol", "timestamp"])
        if dup_pairs.any():
            print(f"Removed {dup_pairs.sum()} duplicate symbol-timestamp pairs.")
            df = df[~dup_pairs]

    # השלמת טווחי זמן חסרים
    df.set_index("timestamp", inplace=True)
    full_range = pd.date_range(start=df.index.min(), end=df.index.max(), freq=expected_interval)
    df = df.reindex(full_range)
    missing_times = df[df.isnull().any(axis=1)].index
    if not missing_times.empty:
        print(f"Filled {len(missing_times)} missing timestamps with NaN.")
    df.reset_index(inplace=True)
    df.rename(columns={"index": "timestamp"}, inplace=True)

    # שמירה מחדש
    df.to_csv(file_path, index=False)
    print("Cleaned file saved.")

# %%
def process_directory(directory):
    # Scan all CSV files in the given directory and check them
    all_files = [f for f in os.listdir(directory) if f.endswith(".csv")]
    for file in all_files:
        file_path = os.path.join(directory, file)
        valid = check_and_clean_csv(file_path)
        if not valid:
            print(f"{file} has issues")

# %%
directory = "data"  # Change this to your actual directory
process_directory(directory)
# Out:
# Checking data\BTCUSDT_15m_full.csv
# Cleaned file saved.
# BTCUSDT_15m_full.csv has issues
#
# Checking data\LTCUSDT_15m_full.csv
# Cleaned file saved.
# LTCUSDT_15m_full.csv has issues
#
# Checking data\LUNA2USDT_15m_full.csv
# Cleaned file saved.
# LUNA2USDT_15m_full.csv has issues
#
# Checking data\MAGICUSDT_15m_full.csv
# Cleaned file saved.
# MAGICUSDT_15m_full.csv has issues
#
# Checking data\MANAUSDT_15m_full.csv
# Cleaned file saved.
# MANAUSDT_15m_full.csv has issues
#
# Checking data\MASKUSDT_15m_full.csv
# Cleaned file saved.
# MASKUSDT_15m_full.csv has issues
#
# Checking data\MAVUSDT_15m_full.csv
# Cleaned file saved.
# MAVUSDT_15m_full.csv has issues
#
# Checking data\MBLUSDT_15m_full.csv
# Cleaned file saved.
# MBLUSDT_15m_full.csv has issues
#
# Checking data\MDTUSDT_15m_full.csv
# Cleaned file saved.
# MDTUSDT_15m_full.csv has issues
#
# Checking data\MINAUSDT_15m_full.csv
# Cleaned file saved.
# MINAUSDT_15m_full.csv has issues
#
# Checking data\MKRUSDT_15m_full.csv
# Cleaned file saved.
# MKRUSDT_15m_full.csv has issues
#
# Checking data\MNTUSDT_15m_full.csv
# Cleaned file saved.
# MNTUSDT_15m_full.csv has issues
#
# Checking data\MOBILEUSDT_15m_full.csv
# Cleaned file saved.
# MOBILEUSDT_15m_full.csv has issues
#
# Checking data\MOVRUSDT_15m_full.csv
# Cleaned file saved.
# MOVRUSDT_15m_full.csv has issues
#
# Checking data\MTLUSDT_15m_full.csv
# Cleaned file saved.
# MTLUSDT_15m_full.csv has issues
#
# Checking data\MYRIAUSDT_15m_full.csv
# Cleaned file saved.
# MYRIAUSDT_15m_full.csv has issues
#
# Checking data\MYROUSDT_15m_full.csv
# Cleaned file saved.
# MYROUSDT_15m_full.csv has issues
#
# Checking data\NEARUSDT_15m_full.csv
# Cleaned file saved.
# NEARUSDT_15m_full.csv has issues
#
# Checking data\NFPUSDT_15m_full.csv
# Cleaned file saved.
# NFPUSDT_15m_full.csv has issues
#
# Checking data\NKNUSDT_15m_full.csv
# Cleaned file saved.
# NKNUSDT_15m_full.csv has issues
#
# Checking data\NMRUSDT_15m_full.csv
# Cleaned file saved.
# NMRUSDT_15m_full.csv has issues
#
# Checking data\NTRNUSDT_15m_full.csv
# Cleaned file saved.
# NTRNUSDT_15m_full.csv has issues
#
# Checking data\OGNUSDT_15m_full.csv
# Cleaned file saved.
# OGNUSDT_15m_full.csv has issues
#
# Checking data\OGUSDT_15m_full.csv
# Cleaned file saved.
# OGUSDT_15m_full.csv has issues
#
# Checking data\OMGUSDT_15m_full.csv
# Cleaned file saved.
# OMGUSDT_15m_full.csv has issues
#
# Checking data\ONEUSDT_15m_full.csv
# Cleaned file saved.
# ONEUSDT_15m_full.csv has issues
#
# Checking data\ONGUSDT_15m_full.csv
# Cleaned file saved.
# ONGUSDT_15m_full.csv has issues
#
# Checking data\ONTUSDT_15m_full.csv
# Cleaned file saved.
# ONTUSDT_15m_full.csv has issues
#
# Checking data\OPUSDT_15m_full.csv
# Cleaned file saved.
# OPUSDT_15m_full.csv has issues
#
# Checking data\ORBSUSDT_15m_full.csv
# Cleaned file saved.
# ORBSUSDT_15m_full.csv has issues
#
# Checking data\ORDIUSDT_15m_full.csv
# Cleaned file saved.
# ORDIUSDT_15m_full.csv has issues
#
# Checking data\OXTUSDT_15m_full.csv
# Cleaned file saved.
# OXTUSDT_15m_full.csv has issues
#
# Checking data\PAXGUSDT_15m_full.csv
# Cleaned file saved.
# PAXGUSDT_15m_full.csv has issues
#
# Checking data\PENDLEUSDT_15m_full.csv
# Cleaned file saved.
# PENDLEUSDT_15m_full.csv has issues
#
# Checking data\PEOPLEUSDT_15m_full.csv
# Cleaned file saved.
# PEOPLEUSDT_15m_full.csv has issues
#
# Checking data\PERPUSDT_15m_full.csv
# Cleaned file saved.
# PERPUSDT_15m_full.csv has issues
#
# Checking data\PHBUSDT_15m_full.csv
# Cleaned file saved.
# PHBUSDT_15m_full.csv has issues
#
# Checking data\POLYXUSDT_15m_full.csv
# Cleaned file saved.
# POLYXUSDT_15m_full.csv has issues
#
# Checking data\POWRUSDT_15m_full.csv
# Cleaned file saved.
# POWRUSDT_15m_full.csv has issues
#
# Checking data\PROMUSDT_15m_full.csv
# Cleaned file saved.
# PROMUSDT_15m_full.csv has issues
#
# Checking data\PYTHUSDT_15m_full.csv
# Cleaned file saved.
# PYTHUSDT_15m_full.csv has issues
#
# Checking data\QIUSDT_15m_full.csv
# Cleaned file saved.
# QIUSDT_15m_full.csv has issues
#
# Checking data\QNTUSDT_15m_full.csv
# Cleaned file saved.
# QNTUSDT_15m_full.csv has issues
#
# Checking data\QTUMUSDT_15m_full.csv
# Cleaned file saved.
# QTUMUSDT_15m_full.csv has issues
#
# Checking data\RADUSDT_15m_full.csv
# Cleaned file saved.
# RADUSDT_15m_full.csv has issues
#
# Checking data\RAREUSDT_15m_full.csv
# Cleaned file saved.
# RAREUSDT_15m_full.csv has issues
#
# Checking data\RDNTUSDT_15m_full.csv
# Cleaned file saved.
# RDNTUSDT_15m_full.csv has issues
#
# Checking data\REQUSDT_15m_full.csv
# Cleaned file saved.
# REQUSDT_15m_full.csv has issues
#
# Checking data\RIFUSDT_15m_full.csv
# Cleaned file saved.
# RIFUSDT_15m_full.csv has issues
#
# Checking data\RLCUSDT_15m_full.csv
# Cleaned file saved.
# RLCUSDT_15m_full.csv has issues
#
# Checking data\ROSEUSDT_15m_full.csv
# Cleaned file saved.
# ROSEUSDT_15m_full.csv has issues
#
# Checking data\RPLUSDT_15m_full.csv
# Cleaned file saved.
# RPLUSDT_15m_full.csv has issues
#
# Checking data\RSRUSDT_15m_full.csv
# Cleaned file saved.
# RSRUSDT_15m_full.csv has issues
#
# Checking data\RSS3USDT_15m_full.csv
# Cleaned file saved.
# RSS3USDT_15m_full.csv has issues
#
# Checking data\RUNEUSDT_15m_full.csv
# Cleaned file saved.
# RUNEUSDT_15m_full.csv has issues
#
# Checking data\RVNUSDT_15m_full.csv
# Cleaned file saved.
# RVNUSDT_15m_full.csv has issues
#
# Checking data\SANDUSDT_15m_full.csv
# Cleaned file saved.
# SANDUSDT_15m_full.csv has issues
#
# Checking data\SCRTUSDT_15m_full.csv
# Cleaned file saved.
# SCRTUSDT_15m_full.csv has issues
#
# Checking data\SCUSDT_15m_full.csv
# Cleaned file saved.
# SCUSDT_15m_full.csv has issues
#
# Checking data\SEIUSDT_15m_full.csv
# Cleaned file saved.
# SEIUSDT_15m_full.csv has issues
#
# Checking data\SFPUSDT_15m_full.csv
# Cleaned file saved.
# SFPUSDT_15m_full.csv has issues
#
# Checking data\SHIB1000USDT_15m_full.csv
# Cleaned file saved.
# SHIB1000USDT_15m_full.csv has issues
#
# Checking data\SKLUSDT_15m_full.csv
# Cleaned file saved.
# SKLUSDT_15m_full.csv has issues
#
# Checking data\SLPUSDT_15m_full.csv
# Cleaned file saved.
# SLPUSDT_15m_full.csv has issues
#
# Checking data\SNTUSDT_15m_full.csv
# Cleaned file saved.
# SNTUSDT_15m_full.csv has issues
#
# Checking data\SPELLUSDT_15m_full.csv
# Cleaned file saved.
# SPELLUSDT_15m_full.csv has issues
#
# Checking data\SSVUSDT_15m_full.csv
# Cleaned file saved.
# SSVUSDT_15m_full.csv has issues
#
# Checking data\STEEMUSDT_15m_full.csv
# Cleaned file saved.
# STEEMUSDT_15m_full.csv has issues
#
# Checking data\STGUSDT_15m_full.csv
# Cleaned file saved.
# STGUSDT_15m_full.csv has issues
#
# Checking data\STORJUSDT_15m_full.csv
# Cleaned file saved.
# STORJUSDT_15m_full.csv has issues
#
# Checking data\STPTUSDT_15m_full.csv
# Cleaned file saved.
# STPTUSDT_15m_full.csv has issues
#
# Checking data\STXUSDT_15m_full.csv
# Cleaned file saved.
# STXUSDT_15m_full.csv has issues
#
# Checking data\SUIUSDT_15m_full.csv
# Cleaned file saved.
# SUIUSDT_15m_full.csv has issues
#
# Checking data\SUNUSDT_15m_full.csv
# Cleaned file saved.
# SUNUSDT_15m_full.csv has issues
#
# Checking data\SUPERUSDT_15m_full.csv
# Cleaned file saved.
# SUPERUSDT_15m_full.csv has issues
#
# Checking data\SUSHIUSDT_15m_full.csv
# Cleaned file saved.
# SUSHIUSDT_15m_full.csv has issues
#
# Checking data\SWEATUSDT_15m_full.csv
# Cleaned file saved.
# SWEATUSDT_15m_full.csv has issues
#
# Checking data\SXPUSDT_15m_full.csv
# Cleaned file saved.
# SXPUSDT_15m_full.csv has issues
#
# Checking data\THETAUSDT_15m_full.csv
# Cleaned file saved.
# THETAUSDT_15m_full.csv has issues
#
# Checking data\TIAUSDT_15m_full.csv
# Cleaned file saved.
# TIAUSDT_15m_full.csv has issues
#
# Checking data\TLMUSDT_15m_full.csv
# Cleaned file saved.
# TLMUSDT_15m_full.csv has issues
#
# Checking data\TOKENUSDT_15m_full.csv
# Cleaned file saved.
# TOKENUSDT_15m_full.csv has issues
#
# Checking data\TONUSDT_15m_full.csv
# Cleaned file saved.
# TONUSDT_15m_full.csv has issues
#
# Checking data\TRBUSDT_15m_full.csv
# Cleaned file saved.
# TRBUSDT_15m_full.csv has issues
#
# Checking data\TRUUSDT_15m_full.csv
# Cleaned file saved.
# TRUUSDT_15m_full.csv has issues
#
# Checking data\TRXUSDT_15m_full.csv
# Cleaned file saved.
# TRXUSDT_15m_full.csv has issues
#
# Checking data\TUSDT_15m_full.csv
# Cleaned file saved.
# TUSDT_15m_full.csv has issues
#
# Checking data\TWTUSDT_15m_full.csv
# Cleaned file saved.
# TWTUSDT_15m_full.csv has issues
#
# Checking data\UMAUSDT_15m_full.csv
# Cleaned file saved.
# UMAUSDT_15m_full.csv has issues
#
# Checking data\UNIUSDT_15m_full.csv
# Cleaned file saved.
# UNIUSDT_15m_full.csv has issues
#
# Checking data\USTCUSDT_15m_full.csv
# Cleaned file saved.
# USTCUSDT_15m_full.csv has issues
